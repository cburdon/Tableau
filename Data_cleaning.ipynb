# %%
import pandas as pd

# %%
file1 = pd.read_csv("./Resources/201701-citibike-tripdata.csv")

# %%
file1.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            680  2017-01-01 00:00:21  2017-01-01 00:11:41              3226
# 1           1282  2017-01-01 00:00:45  2017-01-01 00:22:08              3263
# 2            648  2017-01-01 00:00:57  2017-01-01 00:11:46              3143
# 3            631  2017-01-01 00:01:10  2017-01-01 00:11:42              3143
# 4            621  2017-01-01 00:01:25  2017-01-01 00:11:47              3143
#
#             Start Station Name  Start Station Latitude  \
# 0  W 82 St & Central Park West               40.782750
# 1       Cooper Square & E 7 St               40.729236
# 2              5 Ave & E 78 St               40.776829
# 3              5 Ave & E 78 St               40.776829
# 4              5 Ave & E 78 St               40.776829
#
#    Start Station Longitude  End Station ID             End Station Name  \
# 0               -73.971370            3165  Central Park West & W 72 St
# ...

# %%
file2 = pd.read_csv("./Resources/201702-citibike-tripdata.csv", names=['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID', 'Start Station Name', 'Start Station Latitude',
                    'Start Station Longitude', 'End Station ID', 'End Station Name',
                    'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
                    'Birth Year', 'Gender'])
file3 = pd.read_csv("./Resources/201703-citibike-tripdata.csv", names=['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID', 'Start Station Name', 'Start Station Latitude',
                    'Start Station Longitude', 'End Station ID', 'End Station Name',
                    'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
                    'Birth Year', 'Gender'])
file4 = pd.read_csv("./Resources/201704-citibike-tripdata.csv", names=['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID', 'Start Station Name', 'Start Station Latitude',
                    'Start Station Longitude', 'End Station ID', 'End Station Name',
                    'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
                    'Birth Year', 'Gender'])
file5 = pd.read_csv("./Resources/201705-citibike-tripdata.csv", names=['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID', 'Start Station Name', 'Start Station Latitude',
                    'Start Station Longitude', 'End Station ID', 'End Station Name',
                    'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
                    'Birth Year', 'Gender'])
file6 = pd.read_csv("./Resources/201706-citibike-tripdata.csv", names=['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID', 'Start Station Name', 'Start Station Latitude',
                    'Start Station Longitude', 'End Station ID', 'End Station Name',
                    'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
                    'Birth Year', 'Gender'])
file7 = pd.read_csv("./Resources/201707-citibike-tripdata.csv", names=['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID', 'Start Station Name', 'Start Station Latitude',
                    'Start Station Longitude', 'End Station ID', 'End Station Name',
                    'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
                    'Birth Year', 'Gender'])
file8 = pd.read_csv("./Resources/201708-citibike-tripdata.csv", names=['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID', 'Start Station Name', 'Start Station Latitude',
                    'Start Station Longitude', 'End Station ID', 'End Station Name',
                    'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
                    'Birth Year', 'Gender'])
file9 = pd.read_csv("./Resources/201709-citibike-tripdata.csv", names=['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID', 'Start Station Name', 'Start Station Latitude',
                    'Start Station Longitude', 'End Station ID', 'End Station Name',
                    'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
                    'Birth Year', 'Gender'])
file10 = pd.read_csv("./Resources/201710-citibike-tripdata.csv", names=['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID', 'Start Station Name', 'Start Station Latitude',
                    'Start Station Longitude', 'End Station ID', 'End Station Name',
                    'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
                    'Birth Year', 'Gender'])
file11 = pd.read_csv("./Resources/201711-citibike-tripdata.csv", names=['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID', 'Start Station Name', 'Start Station Latitude',
                    'Start Station Longitude', 'End Station ID', 'End Station Name',
                    'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
                    'Birth Year', 'Gender'])
file12 = pd.read_csv("./Resources/201712-citibike-tripdata.csv", names=['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID', 'Start Station Name', 'Start Station Latitude',
                    'Start Station Longitude', 'End Station ID', 'End Station Name',
                    'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
                    'Birth Year', 'Gender'])
# Out:
# C:\Users\cburd\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (0,3,5,6,7,9,10,11,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
filelist = [file1, file2, file3, file4, file5, file6, file7, file8, file9, file10, file11, file12]
ultimate_file = pd.concat(filelist)
# ultimate_file.columns = ["Trip Duration", "Start Time", "Stop Time", "Start Station ID", "Start Sation Name", "Start Station Latitude", "Start Station Longitude", "Bike ID", "User Type", "Birth Year", "Gender"]
ultimate_file.head()
# Out:
#   Trip Duration           Start Time            Stop Time Start Station ID  \
# 0           680  2017-01-01 00:00:21  2017-01-01 00:11:41             3226
# 1          1282  2017-01-01 00:00:45  2017-01-01 00:22:08             3263
# 2           648  2017-01-01 00:00:57  2017-01-01 00:11:46             3143
# 3           631  2017-01-01 00:01:10  2017-01-01 00:11:42             3143
# 4           621  2017-01-01 00:01:25  2017-01-01 00:11:47             3143
#
#             Start Station Name Start Station Latitude Start Station Longitude  \
# 0  W 82 St & Central Park West                40.7828                -73.9714
# 1       Cooper Square & E 7 St                40.7292                -73.9909
# 2              5 Ave & E 78 St                40.7768                -73.9639
# 3              5 Ave & E 78 St                40.7768                -73.9639
# 4              5 Ave & E 78 St                40.7768                -73.9639
#
# ...

# %%
ultimate_file.tail()
# Out:
#        Trip Duration           Start Time            Stop Time  \
# 889963           397  2017-12-31 23:54:22  2018-01-01 00:01:00
# 889964           332  2017-12-31 23:54:44  2018-01-01 00:00:16
# 889965           565  2017-12-31 23:56:07  2018-01-01 00:05:33
# 889966          1659  2017-12-31 23:57:16  2018-01-01 00:24:56
# 889967          1279  2017-12-31 23:58:56  2018-01-01 00:20:16
#
#        Start Station ID  Start Station Name Start Station Latitude  \
# 889963             3417   Baltic St & 5 Ave                40.6796
# 889964             3236  W 42 St & Dyer Ave                 40.759
# 889965              254     W 11 St & 6 Ave                40.7353
# 889966              495    W 47 St & 10 Ave                40.7627
# 889967             3135     E 75 St & 3 Ave                40.7711
#
#        Start Station Longitude End Station ID              End Station Name  \
# 889963                -73.9785           3418  Plaza St West & Flatbush Ave
# ...

# %%
ultimate_file.shape
# Out:
# (16364668, 15)

# %%
cleaned_sample = ultimate_file.sample(frac=0.01, replace=False, random_state=1)

# %%
cleaned_sample.shape
# Out:
# (163647, 15)

# %%
cleaned_sample.to_csv('concat_sample_.01.csv')
