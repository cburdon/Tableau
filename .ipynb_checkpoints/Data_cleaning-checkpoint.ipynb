# %%
import pandas as pd

# %%
file1 = pd.read_csv("./Resources/201701-citibike-tripdata.csv")

# %%
file1.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            680  2017-01-01 00:00:21  2017-01-01 00:11:41              3226
# 1           1282  2017-01-01 00:00:45  2017-01-01 00:22:08              3263
# 2            648  2017-01-01 00:00:57  2017-01-01 00:11:46              3143
# 3            631  2017-01-01 00:01:10  2017-01-01 00:11:42              3143
# 4            621  2017-01-01 00:01:25  2017-01-01 00:11:47              3143
#
#             Start Station Name  Start Station Latitude  \
# 0  W 82 St & Central Park West               40.782750
# 1       Cooper Square & E 7 St               40.729236
# 2              5 Ave & E 78 St               40.776829
# 3              5 Ave & E 78 St               40.776829
# 4              5 Ave & E 78 St               40.776829
#
#    Start Station Longitude  End Station ID             End Station Name  \
# 0               -73.971370            3165  Central Park West & W 72 St
# ...

# %%
file2 = pd.read_csv("./Resources/201702-citibike-tripdata.csv", header=False)
file3 = pd.read_csv("./Resources/201703-citibike-tripdata.csv", header=False)
file4 = pd.read_csv("./Resources/201704-citibike-tripdata.csv", header=False)
file5 = pd.read_csv("./Resources/201705-citibike-tripdata.csv", header=False)
file6 = pd.read_csv("./Resources/201706-citibike-tripdata.csv", header=False)
file7 = pd.read_csv("./Resources/201707-citibike-tripdata.csv", header=False)
file8 = pd.read_csv("./Resources/201708-citibike-tripdata.csv", header=False)
file9 = pd.read_csv("./Resources/201709-citibike-tripdata.csv", header=False)
file10 = pd.read_csv("./Resources/201710-citibike-tripdata.csv", header=False)
file11 = pd.read_csv("./Resources/201711-citibike-tripdata.csv", header=False)
file12 = pd.read_csv("./Resources/201712-citibike-tripdata.csv", header=False)

# %%
filelist = [file1, file2, file3, file4, file5, file6, file7, file8, file9, file10, file11, file12]
ultimate_file = pd.concat(filelist)
ultimate_file.columns = ["Trip Duration", "Start Time", "Stop Time", "Start Station ID", "Start Sation Name", "Start Station Latitude", "Start Station Longitude", "Bike ID", "User Type", "Birth Year", "Gender"]
ultimate_file.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-faa5f7c1a302> in <module>()
#       1 filelist = [file1, file2, file3, file4, file5, file6, file7, file8, file9, file10, file11, file12]
#       2 ultimate_file = pd.concat(filelist)
# ----> 3 ultimate_file.columns = ["Trip Duration", "Start Time", "Stop Time", "Start Station ID", "Start Sation Name", "Start Station Latitude", "Start Station Longitude", "Bike ID", "User Type", "Birth Year", "Gender"]
#       4 ultimate_file.head()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    3625         try:
#    3626             object.__getattribute__(self, name)
# -> 3627             return object.__setattr__(self, name, value)
#    3628         except AttributeError:
#    3629             pass
#
# ...
